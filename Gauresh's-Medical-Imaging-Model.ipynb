# %%
def augment(data, augmenter):
  if len(data.shape) == 3:
    return augmenter.augment_image(data)
  if len(data.shape) == 4:
    return augmenter.augment_images(data)
    
def rotate(data, rotate):
  fun = augmenters.Affine(rotate = rotate)
  return augment(data, fun)

def shear(data, shear):
  fun = augmenters.Affine(shear = shear)
  return augment(data, fun)

def scale(data, scale):
  fun = augmenters.Affine(scale = scale)
  return augment(data, fun)
  
def flip_left_right(data):
  fun = augmenters.Fliplr(1)
  return augment(data, fun)

def flip_up_down(data):
  fun = augmenters.Flipud(1)
  return augment(data, fun)

def remove_color(data, channel):
  new_data = data.copy()
  if len(data.shape) == 3:
    new_data[:,:,channel] = 0
    return new_data
  if len(data.shape) == 4:
    new_data[:,:,:,channel] = 0
    return new_data
  
class pkg:
  #### DOWNLOADING AND LOADING DATA
  def get_metadata(metadata_path, which_splits = ['train', 'test']):  
    '''returns metadata dataframe which contains columns of:
       * index: index of data into numpy data
       * class: class of image
       * split: which dataset split is this a part of? 
    '''
    metadata = pd.read_csv(metadata_path)
    keep_idx = metadata['split'].isin(which_splits)
    return metadata[keep_idx]

  def get_data_split(split_name, flatten, all_data, metadata, image_shape):
    '''
    returns images (data), labels from folder of format [image_folder]/[split_name]/[class_name]/
    flattens if flatten option is True 
    '''
    sub_df = metadata[metadata['split'].isin([split_name])]
    index  = sub_df['index'].values
    labels = sub_df['class'].values
    data = all_data[index,:]
    if flatten:
      data = data.reshape([-1, np.product(image_shape)])
    return data, labels

  def get_train_data(flatten, all_data, metadata, image_shape):
    return get_data_split('train', flatten, all_data, metadata, image_shape)

  def get_test_data(flatten, all_data, metadata, image_shape):
    return get_data_split('test', flatten, all_data, metadata, image_shape)

  def get_field_data(flatten, all_data, metadata, image_shape):
    return get_data_split('field', flatten, all_data, metadata, image_shape)
  
class helpers:
  #### PLOTTING
  def plot_one_image(data, labels = [], index = None, image_shape = [64,64,3]):
    '''
    if data is a single image, display that image

    if data is a 4d stack of images, display that image
    '''
    num_dims   = len(data.shape)
    num_labels = len(labels)

    # reshape data if necessary
    if num_dims == 1:
      data = data.reshape(target_shape)
    if num_dims == 2:
      data = data.reshape(np.vstack[-1, image_shape])
    num_dims   = len(data.shape)

    # check if single or multiple images
    if num_dims == 3:
      if num_labels > 1:
        print('Multiple labels does not make sense for single image.')
        return

      label = labels      
      if num_labels == 0:
        label = ''
      image = data

    if num_dims == 4:
      image = data[index, :]
      label = labels[index]

    # plot image of interest
    print('Label: %s'%label)
    plt.imshow(image)
    plt.show()

  #### QUERYING AND COMBINING DATA
  def get_misclassified_data(data, labels, predictions):
    '''
    Gets the data and labels that are misclassified in a classification task
    Returns:
    -missed_data
    -missed_labels
    -predicted_labels (corresponding to missed_labels)
    -missed_index (indices of items in original dataset)
    '''
    missed_index     = np.where(np.abs(predictions.squeeze() - labels.squeeze()) > 0)[0]
    missed_labels    = labels[missed_index]
    missed_data      = data[missed_index,:]
    predicted_labels = predictions[missed_index]
    return missed_data, missed_labels, predicted_labels, missed_index

  def combine_data(data_list, labels_list):
    return np.concatenate(data_list, axis = 0), np.concatenate(labels_list, axis = 0)

  def model_to_string(model):
    import re
    stringlist = []
    model.summary(print_fn=lambda x: stringlist.append(x))
    sms = "\n".join(stringlist)
    sms = re.sub('_\d\d\d','', sms)
    sms = re.sub('_\d\d','', sms)
    sms = re.sub('_\d','', sms)  
    return sms

  def plot_acc(history, ax = None, xlabel = 'Epoch #'):
    # i'm sorry for this function's code. i am so sorry. 
    history = history.history
    history.update({'epoch':list(range(len(history['val_accuracy'])))})
    history = pd.DataFrame.from_dict(history)

    best_epoch = history.sort_values(by = 'val_accuracy', ascending = False).iloc[0]['epoch']

    if not ax:
      f, ax = plt.subplots(1,1)
    sns.lineplot(x = 'epoch', y = 'val_accuracy', data = history, label = 'Validation', ax = ax)
    sns.lineplot(x = 'epoch', y = 'accuracy', data = history, label = 'Training', ax = ax)
    ax.axhline(0.5, linestyle = '--',color='red', label = 'Chance')
    ax.axvline(x = best_epoch, linestyle = '--', color = 'green', label = 'Best Epoch')  
    ax.legend(loc = 1)    
    ax.set_ylim([0.4, 1])

    ax.set_xlabel(xlabel)
    ax.set_ylabel('Accuracy (Fraction)')
    
    plt.show()

class models:
  def DenseClassifier(hidden_layer_sizes, nn_params, dropout = 1):
    model = Sequential()
    model.add(Flatten(input_shape = nn_params['input_shape']))
    for ilayer in hidden_layer_sizes:
      model.add(Dense(ilayer, activation = 'relu'))
      if dropout:
        model.add(Dropout(dropout))
    model.add(Dense(units = nn_params['output_neurons'], activation = nn_params['output_activation']))
    model.compile(loss=nn_params['loss'],
                  optimizer=optimizers.SGD(lr=1e-4, momentum=0.95),
                  metrics=['accuracy'])
    return model

  def CNNClassifier(num_hidden_layers, nn_params, dropout = 1):
    model = Sequential()

    model.add(Conv2D(32, (3, 3), input_shape=nn_params['input_shape'], padding = 'same'))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    for i in range(num_hidden_layers-1):
        model.add(Conv2D(32, (3, 3), padding = 'same'))
        model.add(Activation('relu'))
        model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten()) 

    model.add(Dense(units = 128, activation = 'relu'))
    model.add(Dropout(dropout))

    model.add(Dense(units = 64, activation = 'relu'))


    model.add(Dense(units = nn_params['output_neurons'], activation = nn_params['output_activation']))

    # initiate RMSprop optimizer
    opt = keras.optimizers.rmsprop(lr=1e-4, decay=1e-6)

    # Let's train the model using RMSprop
    model.compile(loss=nn_params['loss'],
                  optimizer=opt,
                  metrics=['accuracy'])    
    return model

  def TransferClassifier(name, nn_params, trainable = False):
    expert_dict = {'VGG16': VGG16, 
                   'VGG19': VGG19,
                   'ResNet50':ResNet50,
                   'DenseNet121':DenseNet121}

    expert_conv = expert_dict[name](weights = 'imagenet', 
                                              include_top = False, 
                                              input_shape = nn_params['input_shape'])
    for layer in expert_conv.layers:
      layer.trainable = trainable
      
    expert_model = Sequential()
    expert_model.add(expert_conv)
    expert_model.add(GlobalAveragePooling2D())

    expert_model.add(Dense(128, activation = 'relu'))
    expert_model.add(Dropout(0.3))

    expert_model.add(Dense(64, activation = 'relu'))

    expert_model.add(Dense(nn_params['output_neurons'], activation = nn_params['output_activation']))

    expert_model.compile(loss = nn_params['loss'], 
                  optimizer = optimizers.SGD(lr=1e-4, momentum=0.95), 
                  metrics=['accuracy'])

    return expert_model

import gdown
import zipfile

import os
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn import model_selection

from collections import Counter

import keras
from keras.models import Sequential
from keras.layers import Activation, MaxPooling2D, Dropout, Flatten, Reshape, Dense, Conv2D, GlobalAveragePooling2D
from keras.wrappers.scikit_learn import KerasClassifier
import keras.optimizers as optimizers
from keras.callbacks import ModelCheckpoint

from keras.applications import VGG16, VGG19, ResNet50, DenseNet121

from imgaug import augmenters 

### defining project variables
# file variables
image_data_url       = 'https://drive.google.com/uc?id=1DNEiLAWguswhiLXGyVKsgHIRm1xZggt_'
metadata_url         = 'https://drive.google.com/uc?id=1MW3_FU6qc0qT_uG4bzxhtEHy4Jd6dCWb'
image_data_path      = './image_data.npy'
metadata_path        = './metadata.csv'
image_shape          = (64, 64, 3)

# neural net parameters
nn_params = {}
nn_params['input_shape']       = image_shape
nn_params['output_neurons']    = 1
nn_params['loss']              = 'binary_crossentropy'
nn_params['output_activation'] = 'sigmoid'

###
gdown.download(image_data_url, './image_data.npy', True)
gdown.download(metadata_url, './metadata.csv', True)

### pre-loading all data of interest
_all_data = np.load('image_data.npy')
_metadata = pkg.get_metadata(metadata_path, ['train','test','field'])

### preparing definitions
# downloading and loading data
get_data_split = pkg.get_data_split
get_metadata    = lambda :                 pkg.get_metadata(metadata_path, ['train','test'])
get_train_data  = lambda flatten = False : pkg.get_train_data(flatten = flatten, all_data = _all_data, metadata = _metadata, image_shape = image_shape)
get_test_data   = lambda flatten = False : pkg.get_test_data(flatten = flatten, all_data = _all_data, metadata = _metadata, image_shape = image_shape)
get_field_data  = lambda flatten = False : pkg.get_field_data(flatten = flatten, all_data = _all_data, metadata = _metadata, image_shape = image_shape)

# plotting
plot_one_image = lambda data, labels = [], index = None: helpers.plot_one_image(data = data, labels = labels, index = index, image_shape = image_shape);
plot_acc       = lambda history: helpers.plot_acc(history)

# querying and combining data
model_to_string        = lambda model: helpers.model_to_string(model)
get_misclassified_data = helpers.get_misclassified_data;
combine_data           = helpers.combine_data;

# models with input parameters
DenseClassifier     = lambda hidden_layer_sizes: models.DenseClassifier(hidden_layer_sizes = hidden_layer_sizes, nn_params = nn_params);
CNNClassifier       = lambda num_hidden_layers: models.CNNClassifier(num_hidden_layers, nn_params = nn_params);
TransferClassifier  = lambda name: models.TransferClassifier(name = name, nn_params = nn_params);

monitor = ModelCheckpoint('./model.h5', monitor='val_acc', verbose=0, save_best_only=True, save_weights_only=False, mode='auto', period=1)

# %%
# KNN, LOG, DT

# %%
(train_data, train_labels) = get_train_data(flatten = True)
(test_data, test_labels) = get_test_data(flatten = True)

knn  = KNeighborsClassifier(n_neighbors=20)
log  = LogisticRegression()
dt   = DecisionTreeClassifier(max_depth =5)

# %%
knn.fit(train_data, train_labels)
log.fit(train_data, train_labels)
dt.fit(train_data, train_labels)

print('KNN score: %0.4f'%(knn.score(test_data, test_labels)*100))
print('Log score: %0.4f'%(log.score(test_data, test_labels)*100))
print('DT score: %0.4f'%(dt.score(test_data, test_labels)*100))

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import optimizers

# %%
from sklearn.metrics import classification_report,confusion_matrix

train_data, train_labels = get_train_data()
test_data, test_labels = get_test_data()

#setup the model(s)
dense = DenseClassifier(hidden_layer_sizes = (128,64))
cnn = CNNClassifier(num_hidden_layers = 5)

# fit the model

dense.fit(train_data, train_labels, epochs = 10, validation_data = (test_data, test_labels), shuffle = True, callbacks = [monitor])

cnn.fit(train_data, train_labels, epochs = 25, validation_data = (test_data, test_labels), shuffle = True, callbacks = [monitor])

# %%
print('Dense')
plot_acc(dense.history)

score = dense.evaluate(test_data, test_labels, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])


print('CNN')
plot_acc(cnn.history)

score1 = cnn.evaluate(test_data, test_labels, verbose=0)
print('Test loss:', score1[0])
print('Test accuracy:', score1[1])

# %%
train_data, train_labels = get_train_data()
test_data, test_labels = get_test_data()
transfer = TransferClassifier(name = 'VGG19')
transfer.fit(train_data, train_labels, epochs = 25, validation_data = (test_data, test_labels), shuffle = True, callbacks = [monitor])
plot_acc(transfer.history)

# %%
print('TRANSFER VGG')
plot_acc(transfer.history)

score2 = transfer.evaluate(test_data, test_labels, verbose=0)
print('Test loss:', score2[0])
print('Test accuracy:', score2[1])

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
best_model = transfer

# %%
predictions = best_model.predict_classes(test_data)
confusion = confusion_matrix(test_labels, predictions)
print(confusion)

tp  = confusion[1][1]
tn  = confusion[0][0] 
fp = confusion[0][1]
fn = confusion[1][0]

print('True positive: %d'%tp)
print('True negative: %d'%tn)
print('False positive: %d'%fp)
print('False negative: %d'%fn)

import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(confusion, annot = True, fmt = 'd', cbar_kws={'label':'count'});
plt.ylabel('Actual');
plt.xlabel('Predicted');

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score

print('Accuracy is %d %%'%(accuracy_score(test_labels, predictions)*100.0))
print('Precision is %d %%'%(precision_score(test_labels, predictions)*100.0))
print('Recall is %d %%'%(recall_score(test_labels, predictions)*100.0))

# %%
train_data, train_labels = get_train_data()
test_data, test_labels   = get_test_data()
field_data, field_labels = get_field_data()
  
average_accuracy = 0.0
for i in range(5):
  cnn_old = best_model
  cnn_old.fit(train_data, train_labels, epochs = 20, validation_data = (test_data, test_labels), shuffle = True, callbacks = [monitor])
  
  predictions = cnn_old.predict_classes(field_data)
  accuracy = accuracy_score(field_labels, predictions)
  print('Accuracy on this run: %0.2f' % accuracy)
  
  average_accuracy += accuracy / 5.0
print('Average accuracy: ', average_accuracy)

# %%
# UNDERSTANDING THE PROBLEMS

# %%
[missed_data, missed_labels, predicted_labels, missed_indices] = get_misclassified_data(field_data, field_labels, predictions)

print('How many bad images?')
print(missed_data.shape[0])

print('Which labels are bad?')
print(missed_indices)

# %%
# AUGMENTATION OF DATA TO IMPROVE PERFORMANCE

# %%
IMAGE_INDEX = 0
image = train_data[IMAGE_INDEX,:,:,:]
plot_one_image(shear(image, shear = 10))
plot_one_image(flip_left_right(image))
plot_one_image(flip_up_down(image))
plot_one_image(rotate(image, rotate = 90))
plot_one_image(remove_color(image, channel = 1))

# %%
# make red images
red_train  = remove_color(remove_color(train_data[:1000], channel = 1), channel = 2)
red_labels   = train_labels[:1000]

# make rotated images
rotate_train    = rotate(train_data[1000:2000], rotate = 90)
rotate_labels   = train_labels[1000:2000]

# combine data
all_data, all_labels = combine_data([train_data, rotate_train, red_train], [train_labels, rotate_labels, red_labels])

# %%
train_data, train_labels = get_train_data()
test_data, test_labels   = get_test_data()
field_data, field_labels   = get_field_data()

average_accuracy = 0.0
average_precision = 0.0
average_recall = 0.0

for i in range(5):
  cnn = best_model
  cnn.fit(all_data, all_labels, epochs = 20, validation_data = (test_data, test_labels), shuffle = True, callbacks = [monitor])
  predictions = cnn.predict_classes(field_data)
  accuracy = accuracy_score(field_labels, predictions)
  precision = precision_score(field_labels, predictions)
  recall = recall_score(field_labels, predictions)



print("\n\n")
print('Average accuracy: ', average_accuracy)
print('Average precision: ', average_precision)
print('Average recall: ', average_recall)
# Out:
# Train on 4000 samples, validate on 400 samples
# Epoch 1/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.4641 - accuracy: 0.7715 - val_loss: 0.5435 - val_accuracy: 0.7300
# Epoch 2/20
#   96/4000 [..............................] - ETA: 5s - loss: 0.4355 - accuracy: 0.8125
# /usr/local/lib/python3.6/dist-packages/keras/callbacks/callbacks.py:707: RuntimeWarning: Can save best model only with val_acc available, skipping.
#   'skipping.' % (self.monitor), RuntimeWarning)
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.4056 - accuracy: 0.8012 - val_loss: 0.4531 - val_accuracy: 0.7925
# Epoch 3/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.3803 - accuracy: 0.8242 - val_loss: 0.4733 - val_accuracy: 0.7825
# Epoch 4/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.3650 - accuracy: 0.8380 - val_loss: 0.5411 - val_accuracy: 0.7525
# Epoch 5/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.3553 - accuracy: 0.8443 - val_loss: 0.4926 - val_accuracy: 0.7725
# Epoch 6/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.3491 - accuracy: 0.8468 - val_loss: 0.5195 - val_accuracy: 0.7600
# Epoch 7/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.3367 - accuracy: 0.8565 - val_loss: 0.5677 - val_accuracy: 0.7450
# Epoch 8/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.3356 - accuracy: 0.8635 - val_loss: 0.5377 - val_accuracy: 0.7625
# Epoch 9/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.3258 - accuracy: 0.8620 - val_loss: 0.5974 - val_accuracy: 0.7375
# Epoch 10/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.3199 - accuracy: 0.8710 - val_loss: 0.4802 - val_accuracy: 0.7800
# Epoch 11/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.3128 - accuracy: 0.8755 - val_loss: 0.5549 - val_accuracy: 0.7625
# Epoch 12/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.3104 - accuracy: 0.8765 - val_loss: 0.6038 - val_accuracy: 0.7425
# Epoch 13/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.3044 - accuracy: 0.8765 - val_loss: 0.5728 - val_accuracy: 0.7600
# Epoch 14/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2953 - accuracy: 0.8898 - val_loss: 0.5434 - val_accuracy: 0.7675
# Epoch 15/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2943 - accuracy: 0.8870 - val_loss: 0.5329 - val_accuracy: 0.7675
# Epoch 16/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2937 - accuracy: 0.8888 - val_loss: 0.6298 - val_accuracy: 0.7350
# Epoch 17/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2920 - accuracy: 0.8850 - val_loss: 0.5590 - val_accuracy: 0.7675
# Epoch 18/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2855 - accuracy: 0.8925 - val_loss: 0.6367 - val_accuracy: 0.7375
# Epoch 19/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2828 - accuracy: 0.8910 - val_loss: 0.5382 - val_accuracy: 0.7700
# Epoch 20/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2843 - accuracy: 0.8903 - val_loss: 0.5939 - val_accuracy: 0.7550
# Accuracy:0.78
# Precision:0.72
# Recall:0.92
# Train on 4000 samples, validate on 400 samples
# Epoch 1/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2805 - accuracy: 0.8920 - val_loss: 0.5936 - val_accuracy: 0.7525
# Epoch 2/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2799 - accuracy: 0.8895 - val_loss: 0.5665 - val_accuracy: 0.7650
# Epoch 3/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2744 - accuracy: 0.8965 - val_loss: 0.5843 - val_accuracy: 0.7550
# Epoch 4/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2703 - accuracy: 0.8938 - val_loss: 0.6441 - val_accuracy: 0.7375
# Epoch 5/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2735 - accuracy: 0.8975 - val_loss: 0.6517 - val_accuracy: 0.7375
# Epoch 6/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2698 - accuracy: 0.8940 - val_loss: 0.6735 - val_accuracy: 0.7375
# Epoch 7/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2707 - accuracy: 0.8915 - val_loss: 0.6154 - val_accuracy: 0.7450
# Epoch 8/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2678 - accuracy: 0.8975 - val_loss: 0.6534 - val_accuracy: 0.7400
# Epoch 9/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2607 - accuracy: 0.8995 - val_loss: 0.6806 - val_accuracy: 0.7375
# Epoch 10/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2639 - accuracy: 0.8963 - val_loss: 0.5603 - val_accuracy: 0.7725
# Epoch 11/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2673 - accuracy: 0.8953 - val_loss: 0.5998 - val_accuracy: 0.7525
# Epoch 12/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2558 - accuracy: 0.9025 - val_loss: 0.6325 - val_accuracy: 0.7425
# Epoch 13/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2634 - accuracy: 0.8965 - val_loss: 0.6167 - val_accuracy: 0.7500
# Epoch 14/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2556 - accuracy: 0.8988 - val_loss: 0.6114 - val_accuracy: 0.7475
# Epoch 15/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2537 - accuracy: 0.8997 - val_loss: 0.6917 - val_accuracy: 0.7300
# Epoch 16/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2573 - accuracy: 0.8995 - val_loss: 0.6507 - val_accuracy: 0.7375
# Epoch 17/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2560 - accuracy: 0.8990 - val_loss: 0.6338 - val_accuracy: 0.7475
# Epoch 18/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2515 - accuracy: 0.9005 - val_loss: 0.6193 - val_accuracy: 0.7550
# Epoch 19/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2510 - accuracy: 0.9043 - val_loss: 0.6442 - val_accuracy: 0.7500
# Epoch 20/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2476 - accuracy: 0.9030 - val_loss: 0.5894 - val_accuracy: 0.7650
# Accuracy:0.79
# Precision:0.72
# Recall:0.92
# Train on 4000 samples, validate on 400 samples
# Epoch 1/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2475 - accuracy: 0.9065 - val_loss: 0.6141 - val_accuracy: 0.7575
# Epoch 2/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2442 - accuracy: 0.9050 - val_loss: 0.6846 - val_accuracy: 0.7375
# Epoch 3/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2439 - accuracy: 0.9047 - val_loss: 0.5626 - val_accuracy: 0.7775
# Epoch 4/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2408 - accuracy: 0.9093 - val_loss: 0.6976 - val_accuracy: 0.7400
# Epoch 5/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2426 - accuracy: 0.9055 - val_loss: 0.5334 - val_accuracy: 0.7925
# Epoch 6/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2442 - accuracy: 0.9053 - val_loss: 0.6738 - val_accuracy: 0.7400
# Epoch 7/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2368 - accuracy: 0.9093 - val_loss: 0.6172 - val_accuracy: 0.7550
# Epoch 8/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2429 - accuracy: 0.9122 - val_loss: 0.5935 - val_accuracy: 0.7675
# Epoch 9/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2379 - accuracy: 0.9120 - val_loss: 0.5721 - val_accuracy: 0.7775
# Epoch 10/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2386 - accuracy: 0.9080 - val_loss: 0.5568 - val_accuracy: 0.7825
# Epoch 11/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2383 - accuracy: 0.9105 - val_loss: 0.5927 - val_accuracy: 0.7725
# Epoch 12/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2355 - accuracy: 0.9080 - val_loss: 0.6290 - val_accuracy: 0.7600
# Epoch 13/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2311 - accuracy: 0.9125 - val_loss: 0.6657 - val_accuracy: 0.7400
# Epoch 14/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2355 - accuracy: 0.9065 - val_loss: 0.6144 - val_accuracy: 0.7600
# Epoch 15/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2395 - accuracy: 0.9093 - val_loss: 0.6134 - val_accuracy: 0.7600
# Epoch 16/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2312 - accuracy: 0.9147 - val_loss: 0.7214 - val_accuracy: 0.7350
# Epoch 17/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2276 - accuracy: 0.9160 - val_loss: 0.6349 - val_accuracy: 0.7500
# Epoch 18/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2280 - accuracy: 0.9137 - val_loss: 0.6308 - val_accuracy: 0.7575
# Epoch 19/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2315 - accuracy: 0.9120 - val_loss: 0.5989 - val_accuracy: 0.7725
# Epoch 20/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2279 - accuracy: 0.9147 - val_loss: 0.6209 - val_accuracy: 0.7600
# Accuracy:0.78
# Precision:0.72
# Recall:0.92
# Train on 4000 samples, validate on 400 samples
# Epoch 1/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2292 - accuracy: 0.9128 - val_loss: 0.6042 - val_accuracy: 0.7700
# Epoch 2/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2300 - accuracy: 0.9120 - val_loss: 0.7016 - val_accuracy: 0.7325
# Epoch 3/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2273 - accuracy: 0.9128 - val_loss: 0.6626 - val_accuracy: 0.7475
# Epoch 4/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2246 - accuracy: 0.9120 - val_loss: 0.6446 - val_accuracy: 0.7600
# Epoch 5/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2221 - accuracy: 0.9153 - val_loss: 0.6642 - val_accuracy: 0.7425
# Epoch 6/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2274 - accuracy: 0.9143 - val_loss: 0.5899 - val_accuracy: 0.7700
# Epoch 7/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2242 - accuracy: 0.9150 - val_loss: 0.7344 - val_accuracy: 0.7200
# Epoch 8/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2282 - accuracy: 0.9120 - val_loss: 0.5948 - val_accuracy: 0.7700
# Epoch 9/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2225 - accuracy: 0.9118 - val_loss: 0.6040 - val_accuracy: 0.7725
# Epoch 10/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2178 - accuracy: 0.9165 - val_loss: 0.6096 - val_accuracy: 0.7725
# Epoch 11/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2164 - accuracy: 0.9193 - val_loss: 0.7486 - val_accuracy: 0.7225
# Epoch 12/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2186 - accuracy: 0.9185 - val_loss: 0.6072 - val_accuracy: 0.7725
# Epoch 13/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2224 - accuracy: 0.9162 - val_loss: 0.6167 - val_accuracy: 0.7625
# Epoch 14/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2163 - accuracy: 0.9155 - val_loss: 0.6585 - val_accuracy: 0.7550
# Epoch 15/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2163 - accuracy: 0.9195 - val_loss: 0.6018 - val_accuracy: 0.7675
# Epoch 16/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2178 - accuracy: 0.9158 - val_loss: 0.5814 - val_accuracy: 0.7825
# Epoch 17/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2194 - accuracy: 0.9165 - val_loss: 0.5864 - val_accuracy: 0.7725
# Epoch 18/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2136 - accuracy: 0.9178 - val_loss: 0.6620 - val_accuracy: 0.7625
# Epoch 19/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2161 - accuracy: 0.9178 - val_loss: 0.6773 - val_accuracy: 0.7475
# Epoch 20/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2155 - accuracy: 0.9158 - val_loss: 0.5874 - val_accuracy: 0.7775
# Accuracy:0.78
# Precision:0.72
# Recall:0.92
# Train on 4000 samples, validate on 400 samples
# Epoch 1/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2112 - accuracy: 0.9220 - val_loss: 0.6240 - val_accuracy: 0.7650
# Epoch 2/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2119 - accuracy: 0.9190 - val_loss: 0.5523 - val_accuracy: 0.7925
# Epoch 3/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2109 - accuracy: 0.9200 - val_loss: 0.6154 - val_accuracy: 0.7700
# Epoch 4/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2099 - accuracy: 0.9235 - val_loss: 0.6193 - val_accuracy: 0.7650
# Epoch 5/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2089 - accuracy: 0.9208 - val_loss: 0.6021 - val_accuracy: 0.7775
# Epoch 6/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2149 - accuracy: 0.9172 - val_loss: 0.6759 - val_accuracy: 0.7475
# Epoch 7/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2069 - accuracy: 0.9212 - val_loss: 0.6087 - val_accuracy: 0.7675
# Epoch 8/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2139 - accuracy: 0.9160 - val_loss: 0.6798 - val_accuracy: 0.7425
# Epoch 9/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2115 - accuracy: 0.9202 - val_loss: 0.5688 - val_accuracy: 0.7825
# Epoch 10/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2042 - accuracy: 0.9218 - val_loss: 0.5689 - val_accuracy: 0.7825
# Epoch 11/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2120 - accuracy: 0.9208 - val_loss: 0.5187 - val_accuracy: 0.7950
# Epoch 12/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2080 - accuracy: 0.9178 - val_loss: 0.5901 - val_accuracy: 0.7825
# Epoch 13/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2049 - accuracy: 0.9208 - val_loss: 0.6109 - val_accuracy: 0.7675
# Epoch 14/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2044 - accuracy: 0.9225 - val_loss: 0.7110 - val_accuracy: 0.7400
# Epoch 15/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2049 - accuracy: 0.9220 - val_loss: 0.7173 - val_accuracy: 0.7300
# Epoch 16/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2026 - accuracy: 0.9230 - val_loss: 0.6443 - val_accuracy: 0.7600
# Epoch 17/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2076 - accuracy: 0.9220 - val_loss: 0.5898 - val_accuracy: 0.7750
# Epoch 18/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2060 - accuracy: 0.9208 - val_loss: 0.6182 - val_accuracy: 0.7675
# Epoch 19/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.2028 - accuracy: 0.9240 - val_loss: 0.6451 - val_accuracy: 0.7650
# Epoch 20/20
# 4000/4000 [==============================] - 6s 1ms/step - loss: 0.1997 - accuracy: 0.9237 - val_loss: 0.7145 - val_accuracy: 0.7425
# Accuracy:0.76
# Precision:0.69
# Recall:0.96
#
#
#
# Average accuracy:  0.7779999999999999
# Average precision:  0.7143300238561261
# Average recall:  0.9280000000000002
